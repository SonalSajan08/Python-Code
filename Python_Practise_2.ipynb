# %% [markdown]
# <a href="https://colab.research.google.com/github/SonalSajan08/Python-Code/blob/main/Python_Practise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Python Practise 2***

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/california_housing_test.csv")

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.size
# Out:
# 27000

# %%
df.shape
# Out:
# (3000, 9)

# %%
ros=df.tail(20)

# %%
#Descriptive Statistics
ros.describe()
# Out:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# count   20.000000  20.000000           20.000000    20.000000        20.00000
# mean  -119.578500  35.269500           31.950000  2179.700000       475.05000
# std      1.844866   1.520223           13.128815  1474.090267       287.47274
# min   -122.540000  33.600000           10.000000    96.000000        14.00000
# 25%   -120.987500  34.075000           21.500000  1210.250000       255.50000
# 50%   -119.665000  34.420000           33.500000  1701.500000       464.00000
# 75%   -118.087500  36.835000           42.000000  2678.000000       661.00000
# max   -117.120000  37.900000           52.000000  5257.000000      1082.00000
#
#         population  households  median_income  median_house_value
# count    20.000000    20.00000      20.000000           20.000000
# mean   1226.500000   430.80000       3.798700       229200.150000
# std     854.201412   269.61739       1.977753       140123.232381
# ...

# %%
ros.max()
# Out:
# longitude               -117.1200
# latitude                  37.9000
# housing_median_age        52.0000
# total_rooms             5257.0000
# total_bedrooms          1082.0000
# population              3496.0000
# households              1036.0000
# median_income              8.5608
# median_house_value    500001.0000
# dtype: float64

# %%
ros.min()
# Out:
# longitude              -122.5400
# latitude                 33.6000
# housing_median_age       10.0000
# total_rooms              96.0000
# total_bedrooms           14.0000
# population               46.0000
# households               14.0000
# median_income             1.1346
# median_house_value    62000.0000
# dtype: float64

# %%
ros.mean()
# Out:
# longitude               -119.5785
# latitude                  35.2695
# housing_median_age        31.9500
# total_rooms             2179.7000
# total_bedrooms           475.0500
# population              1226.5000
# households               430.8000
# median_income              3.7987
# median_house_value    229200.1500
# dtype: float64

# %%
#Standard Deviation
ros.std()
# Out:
# longitude                  1.844866
# latitude                   1.520223
# housing_median_age        13.128815
# total_rooms             1474.090267
# total_bedrooms           287.472740
# population               854.201412
# households               269.617390
# median_income              1.977753
# median_house_value    140123.232381
# dtype: float64

# %%
#Picks a random row
ros.sample()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2985    -120.47     34.94                17.0       1368.0           308.0
#
#       population  households  median_income  median_house_value
# 2985       642.0       303.0         1.8633            109400.0

# %%
#Drops NA values
ros.dropna()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2980    -119.76     36.79                32.0       2463.0           468.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2982    -118.28     34.08                42.0       1618.0           522.0
# 2983    -122.54     37.90                48.0       2491.0           460.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# ...

# %%
ros.sample(4)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
#
#       population  households  median_income  median_house_value
# 2986       899.0       228.0         1.1346             85400.0
# 2997       693.0       220.0         2.2895             62000.0
# 2989      1097.0       328.0         3.2386            149600.0
# 2990      1500.0       430.0         2.6923            150000.0

# %%
#Chain operation
ros.head(10).mean()
# Out:
# longitude               -120.35500
# latitude                  35.88700
# housing_median_age        31.10000
# total_rooms             2397.30000
# total_bedrooms           533.20000
# population              1458.30000
# households               514.30000
# median_income              3.04735
# median_house_value    181100.00000
# dtype: float64

# %%
#Selecting a column
ros.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
ros['total_rooms'].mean()
# Out:
# 2179.7

# %%
ros[['total_rooms']]
# Out:
#       total_rooms
# 2980       2463.0
# 2981       4422.0
# 2982       1618.0
# 2983       2491.0
# 2984       3239.0
# 2985       1368.0
# 2986        819.0
# 2987       4096.0
# 2988       2162.0
# 2989       1295.0
# 2990       1638.0
# 2991       4867.0
# 2992        573.0
# 2993       2088.0
# 2994        931.0
# 2995       1450.0
# 2996       5257.0
# 2997        956.0
# 2998         96.0
# 2999       1765.0

# %%
ros.latitude.describe()
# Out:
# count    20.000000
# mean     35.269500
# std       1.520223
# min      33.600000
# 25%      34.075000
# 50%      34.420000
# 75%      36.835000
# max      37.900000
# Name: latitude, dtype: float64

# %%
#Groupby method
ros_la=ros.groupby(['latitude'])
ros_la.mean()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 33.60      -117.910                37.0       2088.0           510.0
# 33.86      -117.930                35.0        931.0           181.0
# 33.88      -117.590                13.0       3239.0           849.0
# 33.93      -118.250                42.0        819.0           233.0
# 34.06      -118.140                27.0       5257.0          1082.0
# 34.08      -118.280                42.0       1618.0           522.0
# 34.09      -118.230                49.0       1638.0           456.0
# 34.10      -117.120                40.0         96.0            14.0
# 34.28      -117.170                13.0       4867.0           718.0
# 34.42      -119.745                32.5       1607.5           452.5
# 34.94      -120.470                17.0       1368.0           308.0
# 35.49      -120.660                17.0       4422.0           945.0
# ...

# %%
ros[ros['latitude']>35]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2980    -119.76     36.79                32.0       2463.0           468.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2983    -122.54     37.90                48.0       2491.0           460.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2997    -119.70     36.30                10.0        956.0           201.0
#
#       population  households  median_income  median_house_value
# 2980      1261.0       486.0         3.3281             75100.0
# 2981      2307.0       885.0         2.8285            171300.0
# 2983       937.0       455.0         4.4375            370000.0
# ...

# %%
#to select more than one column
ros [['latitude','longitude']]
# Out:
#       latitude  longitude
# 2980     36.79    -119.76
# 2981     35.49    -120.66
# 2982     34.08    -118.28
# 2983     37.90    -122.54
# 2984     33.88    -117.59
# 2985     34.94    -120.47
# 2986     33.93    -118.25
# 2987     37.29    -121.97
# 2988     36.97    -122.01
# 2989     37.60    -122.02
# 2990     34.09    -118.23
# 2991     34.28    -117.17
# 2992     37.39    -122.33
# 2993     33.60    -117.91
# 2994     33.86    -117.93
# 2995     34.42    -119.86
# 2996     34.06    -118.14
# 2997     36.30    -119.70
# 2998     34.10    -117.12
# 2999     34.42    -119.63

# %%
#Extracting 1 to 10 rows and 1 to 3 columns
ros.iloc[0:10,0:3]
# Out:
#       longitude  latitude  housing_median_age
# 2980    -119.76     36.79                32.0
# 2981    -120.66     35.49                17.0
# 2982    -118.28     34.08                42.0
# 2983    -122.54     37.90                48.0
# 2984    -117.59     33.88                13.0
# 2985    -120.47     34.94                17.0
# 2986    -118.25     33.93                42.0
# 2987    -121.97     37.29                25.0
# 2988    -122.01     36.97                43.0
# 2989    -122.02     37.60                32.0

# %%
#Extracting 5th and 6th column
ros.iloc[:,[5,6]]
# Out:
#       population  households
# 2980      1261.0       486.0
# 2981      2307.0       885.0
# 2982      1454.0       440.0
# 2983       937.0       455.0
# 2984      2751.0       813.0
# 2985       642.0       303.0
# 2986       899.0       228.0
# 2987      2027.0       741.0
# 2988      1208.0       464.0
# 2989      1097.0       328.0
# 2990      1500.0       430.0
# 2991       780.0       250.0
# 2992       232.0        92.0
# 2993       673.0       390.0
# 2994       516.0       174.0
# 2995      1258.0       607.0
# 2996      3496.0      1036.0
# 2997       693.0       220.0
# 2998        46.0        14.0
# 2999       753.0       260.0

# %%
#Extracting 8th row as in python index starts from 0
ros.iloc[9]
# Out:
# longitude               -122.0200
# latitude                  37.6000
# housing_median_age        32.0000
# total_rooms             1295.0000
# total_bedrooms           295.0000
# population              1097.0000
# households               328.0000
# median_income              3.2386
# median_house_value    149600.0000
# Name: 2989, dtype: float64

# %%
#Extracting 1st and 3rd column
ros.iloc[[0,2]]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2980    -119.76     36.79                32.0       2463.0           468.0
# 2982    -118.28     34.08                42.0       1618.0           522.0
#
#       population  households  median_income  median_house_value
# 2980      1261.0       486.0         3.3281             75100.0
# 2982      1454.0       440.0         3.1607            182000.0

# %%
#Aggregation function - Summarizing the entire columns
ros [['longitude','total_rooms']].agg(['mean','max','mad','skew','kurt','sem'])
# Out:
#        longitude  total_rooms
# mean -119.578500  2179.700000
# max  -117.120000  5257.000000
# mad     1.558650  1157.710000
# skew   -0.331870     0.850471
# kurt   -1.331991    -0.218754
# sem     0.412524   329.616604
